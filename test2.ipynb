# %%
from ultralytics import YOLO

# %%
from ultralytics import YOLO
trained_model = YOLO(r'C:\Users\saksh\Test1\runs\detect\train5\weights\best.pt')
results = trained_model(r'C:\Users\saksh\Test1\train\images\79-5-_jpg.rf.7dadbe6cb0fde7a7d4611cce9396ef91.jpg')
import matplotlib.pyplot as plt
from PIL import Image
# Ensure matplotlib inline mode
# %matplotlib inline
# Assuming results[0].plot() returns an array
image_array = results[0].plot()   

# Display the image
plt.imshow(image_array)
plt.axis('off')  # Hide axes
plt.show()
# Out:
# image 1/1 C:\Users\saksh\Test1\train\images\79-5-_jpg.rf.7dadbe6cb0fde7a7d4611cce9396ef91.jpg: 640x640 1 lesion, 66.1ms
# Speed: 2.0ms preprocess, 66.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
import matplotlib.pyplot as plt
from PIL import Image
# Ensure matplotlib inline mode
# %matplotlib inline
# Assuming results[0].plot() returns an array
image_array = results[0].plot()

# Display the image
plt.imshow(image_array)
plt.axis('off')  # Hide axes
plt.show()
